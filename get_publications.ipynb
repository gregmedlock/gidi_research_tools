# %%
import scholarly
import pandas
import time
import datetime

# %%
# load the gidi-affiliated faculty list
faculty = pandas.read_csv('./data/gidi_faculty_list.tsv',sep='\t',header=None)
faculty.columns = ['name']
faculty
# Out:
#                  name
# 0       Herve Agaisse
# 1          Huiwang Ai
# 2    Janis Antonovics
# 3       Lawrence Band
# 4        Laura Barnes
# ..                ...
# 128      Ozlem Yildiz
# 129   Steven Zeichner
# 130      Jianhui Zhou
# 131     Jarrett Zigon
# 132     Jochen Zimmer
#
# [133 rows x 1 columns]

# %%
# identify which faculty have google scholar profiles
MAX_ITERS = 3
def query_profiles(name, existing_query=None, iteration=0):
    '''
    Recursive function to query google scholar profiles. Returns the scholar ID if it
    is found within the first MAX_ITERS searches, otherwise returns None.
    '''
    if existing_query:
        query = existing_query
    else:
        query = scholarly.search_author(name)
    
    try:
        query_hit = next(query)
        email_affiliation = query_hit.email
        # if the email address is a virginia address, this is probably the right profile
        if email_affiliation.find('virginia') > -1:
            query_hit.fill()
            profile = query_hit
        # otherwise, recurse through the function up to MAX_ITERS
        else:
            iteration+=1
            if iteration < MAX_ITERS:
                profile = query_profiles(name,existing_query=query,iteration=iteration)
            else:
                profile = None
    except StopIteration:
        profile = None
        
    if not profile:
        print('No google scholar profile hits for ' + name)
    return profile

no_profile = []
current_year_pubs = {}
for name in faculty['name']:
    print(name)
    profile = query_profiles(name)
    if not profile: 
        no_profile.append(name)
    else:
        # get all publications within the current year
        current_year_pubs[name] = []
        for pub in profile.publications:
            if 'year' in pub.bib.keys(): # some publications don't include the year/date
                if pub.bib['year'] == datetime.datetime.now().year:
                    current_year_pubs[name].append(pub.bib.copy())
# Out:
# Herve Agaisse
# No google scholar profile hits for Herve Agaisse
# Huiwang Ai
# Janis Antonovics
# No google scholar profile hits for Janis Antonovics
# Lawrence Band
# Laura Barnes
# Christopher L. Barrett
# Ruth Gaare Bernheim
# No google scholar profile hits for Ruth Gaare Bernheim
# Sam Bodily
# Phillip Bourne
# Thomas Braciale
# No google scholar profile hits for Thomas Braciale
# Catherine Bradshaw
# Michael G. Brown
# Timothy Bullock
# No google scholar profile hits for Timothy Bullock
# Anselmo Canfora
# No google scholar profile hits for Anselmo Canfora
# James Casanova
# No google scholar profile hits for James Casanova
# Anna Cliffe
# No google scholar profile hits for Anna Cliffe
# Linda Columbus
# Alison Criss
# Cristian Danna
# No google scholar profile hits for Cristian Danna
# Ashley Deeks
# No google scholar profile hits for Ashley Deeks
# Isabelle Derre
# No google scholar profile hits for Isabelle Derre
# Zygmunt Derwenda
# Rebecca Dillingham
# No google scholar profile hits for Rebecca Dillingham
# Marcel Durieux
# Joshua Eby
# No google scholar profile hits for Joshua Eby
# Edward Egelman
# Daniel Engel
# No google scholar profile hits for Daniel Engel
# No google scholar profile hits for Daniel Engel
# Stephen Eubank
# Sarah Ewald
# Roseanne Ford
# No google scholar profile hits for Roseanne Ford
# No google scholar profile hits for Roseanne Ford
# Mary Margaret Frank
# Gertrude Fraser
# No google scholar profile hits for Gertrude Fraser
# Brent French
# No google scholar profile hits for Brent French
# No google scholar profile hits for Brent French
# Andreas Gahlmann
# Kirsten Gelsdorf
# Amanda Gibson
# Carol Gilchrist
# Jorge Giron
# No google scholar profile hits for Jorge Giron
# No google scholar profile hits for Jorge Giron
# Don Griffin
# Gianluca Guadagni
# No google scholar profile hits for Gianluca Guadagni
# Richard Guerrant
# No google scholar profile hits for Richard Guerrant
# William Guilford
# Jennifer Guler
# Young S. Hahn
# No google scholar profile hits for Young S. Hahn
# Marie-Louise Hammarskjold
# Rachel Harmon
# Tajie Harris
# Farzad Hassanzadeh
# Frederick Hayden
# No google scholar profile hits for Frederick Hayden
# Ann Hays
# No google scholar profile hits for Ann Hays
# No google scholar profile hits for Ann Hays
# Brian Helmke
# No google scholar profile hits for Brian Helmke
# Scott Heysell
# No google scholar profile hits for Scott Heysell
# Eric Houpt
# No google scholar profile hits for Eric Houpt
# James Howe
# Ku-Lung Hsu
# Molly Hughes
# No google scholar profile hits for Molly Hughes
# Donald F. Hunt
# Brant Isakson
# Kevin Janes
# Peter Kasson
# Dean Kedes
# Jessica Keim Malpass
# Kimberly Kelly
# Melissa Kendall
# No google scholar profile hits for Melissa Kendall
# Mark Kester
# No google scholar profile hits for Mark Kester
# Michael L. King
# No google scholar profile hits for Michael L. King
# No google scholar profile hits for Michael L. King
# Glynis Kolling
# No google scholar profile hits for Glynis Kolling
# Susan Kools
# No google scholar profile hits for Susan Kools
# Gerard Learmonth
# David Leblang
# No google scholar profile hits for David Leblang
# No google scholar profile hits for David Leblang
# Manuel Lerdau
# Bryan Lewis
# Garrick Louis
# Jennie Ma
# No google scholar profile hits for Jennie Ma
# No google scholar profile hits for Jennie Ma
# No google scholar profile hits for Jennie Ma
# Barbara Mann
# No google scholar profile hits for Barbara Mann
# No google scholar profile hits for Barbara Mann
# Madhav Marathe
# Achla Marathe
# Amy Mathers
# No google scholar profile hits for Amy Mathers
# Joann McDermid
# Kathleen McManus
# No google scholar profile hits for Kathleen McManus
# Christian McMillen
# No google scholar profile hits for Christian McMillen
# Daniel Mietchen
# Wladek Minor
# Emma Mitchell
# No google scholar profile hits for Emma Mitchell
# No google scholar profile hits for Emma Mitchell
# No google scholar profile hits for Emma Mitchell
# Christopher Moore
# No google scholar profile hits for Christopher Moore
# No google scholar profile hits for Christopher Moore
# No google scholar profile hits for Christopher Moore
# Sean Moore
# Cameron Mura
# Noah Myung
# No google scholar profile hits for Noah Myung
# Robert Nakamoto
# No google scholar profile hits for Robert Nakamoto
# James Nataro
# No google scholar profile hits for James Nataro
# Amanda Nguyen
# No google scholar profile hits for Amanda Nguyen
# No google scholar profile hits for Amanda Nguyen
# No google scholar profile hits for Amanda Nguyen
# Jason Papin
# SM Peirce
# Lisa Peterson
# No google scholar profile hits for Lisa Peterson
# William Petri
# James Platts-Mills
# Rebecca Pompano
# Owen Pornillos
# Phillip Potter
# Girija Ramakrishnan
# No google scholar profile hits for Girija Ramakrishnan
# David Rekosh
# Stephen S. Rich
# No google scholar profile hits for Stephen S. Rich
# No google scholar profile hits for Stephen S. Rich
# No google scholar profile hits for Stephen S. Rich
# Elizabeth Rogawski
# Jennifer Rubenstein
# No google scholar profile hits for Jennifer Rubenstein
# Melanie Rutkowski
# No google scholar profile hits for Melanie Rutkowski
# Rebecca Scharf
# China Scherz
# Heman Shakeri
# John Shepherd
# No google scholar profile hits for John Shepherd
# No google scholar profile hits for John Shepherd
# No google scholar profile hits for John Shepherd
# Lois Shepherd
# Costi Sifri
# Jim Smith
# No google scholar profile hits for Jim Smith
# No google scholar profile hits for Jim Smith
# No google scholar profile hits for Jim Smith
# Nathan Swami
# Sana Syed
# Lukas Tamm
# No google scholar profile hits for Lukas Tamm
# Gang Tao
# Sebastian Tello-Trillo
# Tania Thomas
# No google scholar profile hits for Tania Thomas
# No google scholar profile hits for Tania Thomas
# Michael Timko
# No google scholar profile hits for Michael Timko
# No google scholar profile hits for Michael Timko
# Sankaran Venkataraman
# Srini Venkatramanan
# No google scholar profile hits for Srini Venkatramanan
# No google scholar profile hits for Srini Venkatramanan
# No google scholar profile hits for Srini Venkatramanan
# Cirle Warren
# No google scholar profile hits for Cirle Warren
# Judith White
# No google scholar profile hits for Judith White
# No google scholar profile hits for Judith White
# Andy Wicks
# Michael Wiener
# No google scholar profile hits for Michael Wiener
# No google scholar profile hits for Michael Wiener
# No google scholar profile hits for Michael Wiener
# Michael Williams
# No google scholar profile hits for Michael Williams
# No google scholar profile hits for Michael Williams
# No google scholar profile hits for Michael Williams
# Martin Wu
# Mark Yeager
# Ozlem Yildiz
# No google scholar profile hits for Ozlem Yildiz
# No google scholar profile hits for Ozlem Yildiz
# No google scholar profile hits for Ozlem Yildiz
# Steven Zeichner
# No google scholar profile hits for Steven Zeichner
# Jianhui Zhou
# No google scholar profile hits for Jianhui Zhou
# No google scholar profile hits for Jianhui Zhou
# No google scholar profile hits for Jianhui Zhou
# Jarrett Zigon
# Jochen Zimmer

# %%
pub_to_frame = {}
pub_count = 0
for author, pubs in current_year_pubs.items():
    for pub in pubs:
        pub_count+=1
        pub_id = 'pub'+str(pub_count)
        title = pub['title']
        pub_to_frame[pub_id] = {'Author':author,
                                'Title':pub['title'],
                                'year_recorded':datetime.datetime.now().year,
                                     'month_recorded':datetime.datetime.now().month,
                                     'day_recorded':datetime.datetime.now().day}
pub_to_frame = pandas.DataFrame(pub_to_frame).T
# Make the titles uppercase to avoid missing duplicates due to case differences
pub_to_frame['Title'] = pub_to_frame['Title'].str.upper()
pub_to_frame
# Out:
#                Author                                              Title  \
# pub1       Huiwang Ai  DEVELOPMENT AND APPLICATIONS OF BIOLUMINESCENT...
# pub2       Huiwang Ai  RED-SHIFTED LUCIFERASE-LUCIFERIN PAIRS FOR ENH...
# pub3       Huiwang Ai  IDENTIFICATION OF FACTORS COMPLICATING BIOLUMI...
# pub4       Huiwang Ai  A GENETICALLY ENCODED, RATIOMETRIC FLUORESCENT...
# pub5       Huiwang Ai  ATP-INDEPENDENT BIOLUMINESCENT REPORTER VARIAN...
# ...               ...                                                ...
# pub533  Jarrett Zigon  TRAVELING WITH SUGAR: CHRONICLES OF A GLOBAL E...
# pub534  Jarrett Zigon  SACRIFICIAL LIMBS: MASCULINITY, DISABILITY, AN...
# pub535  Jochen Zimmer  A LIPID GATING MECHANISM FOR THE CHANNEL-FORMI...
# pub536  Jochen Zimmer  STRUCTURAL FEATURES UNDERLYING RECOGNITION AND...
# pub537  Jochen Zimmer  ARCHITECTURE OF THE CELLULOSE SYNTHASE OUTER M...
#
#        year_recorded month_recorded day_recorded
# pub1            2019             12            9
# pub2            2019             12            9
# pub3            2019             12            9
# pub4            2019             12            9
# pub5            2019             12            9
# ...              ...            ...          ...
# pub533          2019             12            9
# pub534          2019             12            9
# pub535          2019             12            9
# pub536          2019             12            9
# pub537          2019             12            9
#
# [537 rows x 5 columns]

# %%
# Find publications that appear more than once in the list; these involve multiple GIDI faculty
len(pub_to_frame['Title'])
len(set(pub_to_frame['Title']))
l = list(pub_to_frame['Title'])
set([x for x in l if l.count(x) > 1])
# Out:
# {'3165 DISEASED AND HEALTHY GASTROINTESTINAL TISSUE DATA MINING REQUIRES AN ENGAGED TRANSDISCIPLINARY TEAM',
#  'A MOLECULAR MODEL OF THE ALPHA GLOBIN/ENOS COMPLEX',
#  'A NOVEL RETROVIRAL VECTOR SYSTEM TO ANALYZE EXPRESSION FROM MRNA WITH RETAINED INTRONS USING FLUORESCENT PROTEINS AND FLOW CYTOMETRY',
#  'A ONE HEALTH APPROACH TO PREVENTION, TREATMENT, AND CONTROL OF CAMPYLOBACTERIOSIS',
#  'AN ASSAY TO MEASURE THE ACTIVITY OF RNA ELEMENTS AND PROTEINS THAT PROMOTE THE EXPRESSION OF MRNA WITH RETAINED INTRONS',
#  'ARCHITECTURE OF THE CELLULOSE SYNTHASE OUTER MEMBRANE CHANNEL AND ITS ASSOCIATION WITH THE PERIPLASMIC TPR DOMAIN',
#  'ARTIFICIAL INTELLIGENCE APPLIED TO GASTROINTESTINAL DIAGNOSTICS: A REVIEW',
#  'ASSESSMENT OF MACHINE LEARNING DETECTION OF ENVIRONMENTAL ENTEROPATHY AND CELIAC DISEASE IN CHILDREN',
#  'CHARACTERIZATION OF APOBEC3 VARIATION IN A POPULATION OF HIV-1 INFECTED INDIVIDUALS IN NORTHERN SOUTH AFRICA',
#  'COMPARATIVE ANALYSES OF PARASITES WITH A COMPREHENSIVE DATABASE OF GENOME-SCALE METABOLIC MODELS',
#  'CONSTITUTIVE SRC-MEDIATED PHOSPHORYLATION OF PANNEXIN 1 AT TYROSINE 198 OCCURS AT THE PLASMA MEMBRANE',
#  'CRYO-EM STRUCTURE OF THE CFA/I PILUS ROD',
#  'CUMULATIVE PSYCHOSOCIAL RISK AND EARLY CHILD DEVELOPMENT: VALIDATION AND USE OF THE CHILDHOOD PSYCHOSOCIAL ADVERSITY SCALE IN GLOBAL HEALTH RESEARCH',
#  'DEEP LEARNING FOR DETECTING DISEASES IN GASTROINTESTINAL BIOPSY IMAGES',
#  'DEEP LEARNING FOR VISUAL RECOGNITION OF ENVIRONMENTAL ENTEROPATHY AND CELIAC DISEASE',
#  'DIAGNOSIS OF CELIAC DISEASE AND ENVIRONMENTAL ENTEROPATHY ON BIOPSY IMAGES USING COLOR BALANCING ON CONVOLUTIONAL NEURAL NETWORKS',
#  'DUODENAL BIOPSIES CLASSIFICATION AND UNDERSTANDING USING CONVOLUTIONAL NEURAL NETWORKS',
#  'EARLY LIFE CHILD MICRONUTRIENT STATUS, MATERNAL REASONING, AND A NURTURING HOUSEHOLD ENVIRONMENT HAVE PERSISTENT INFLUENCES ON CHILD COGNITIVE DEVELOPMENT AT AGE 5 YEARS …',
#  'ELECTROFABRICATED BIOMATERIAL-BASED CAPACITOR ON NANOPOROUS GOLD FOR ENHANCED REDOX AMPLIFICATION',
#  'ENABLING TECHNOLOGIES IN SUPER-RESOLUTION FLUORESCENCE MICROSCOPY: REPORTERS, LABELING, AND METHODS OF MEASUREMENT',
#  'ENDOTHELIAL ALPHA HEMOGLOBIN IS A NITRITE REDUCTASE',
#  'ENTERIC DYSFUNCTION AND OTHER FACTORS ASSOCIATED WITH ATTAINED SIZE AT 5 YEARS: MAL-ED BIRTH COHORT STUDY FINDINGS',
#  'ENTEROPATHOGENS WERE NOT ASSOCIATED WITH ROTAVIRUS VACCINE IMMUNOGENICITY IN A CLUSTER-RANDOMIZED TRIAL OF IMPROVED WATER, SANITATION AND HYGIENE IN RURAL ZIMBABWE',
#  'EVOLUTION OF THE HIV-1 REV RESPONSE ELEMENT DURING NATURAL INFECTION REVEALS NUCLEOTIDE CHANGES THAT CORRELATE WITH ALTERED STRUCTURE AND INCREASED ACTIVITY OVER TIME',
#  'FECAL IGA AGAINST A SPOROZOITE ANTIGEN AT 12 MONTHS IS ASSOCIATED WITH DELAYED TIME TO SUBSEQUENT CRYPTOSPORIDIOSIS IN URBAN BANGLADESH: A PROSPECTIVE COHORT STUDY.',
#  'FECAL IMMUNOGLOBULIN A AGAINST A SPOROZOITE ANTIGEN AT 12 MONTHS IS ASSOCIATED WITH DELAYED TIME TO SUBSEQUENT CRYPTOSPORIDIOSIS IN URBAN BANGLADESH: A PROSPECTIVE COHORT STUDY',
#  'HETEROCELLULAR CONTACT CAN DICTATE ARTERIAL FUNCTION',
#  'HETEROGENEITY IN PRICE SENSITIVITY: THE ROLE OF PRICES AND WEALTH',
#  'HIV-1 REV INTERACTS WITH HERV-K RCRES PRESENT IN THE HUMAN GENOME AND PROMOTES EXPORT OF UNSPLICED HERV-K PROVIRAL RNA',
#  'IMPACT OF WATER QUALITY, SANITATION, HANDWASHING, AND NUTRITIONAL INTERVENTIONS ON ENTERIC INFECTIONS IN RURAL ZIMBABWE: THE SANITATION HYGIENE INFANT NUTRITION EFFICACY (SHINE …',
#  'INCREASED FECAL LACTOBACILLUS IS ASSOCIATED WITH A POSITIVE GLUCOSE HYDROGEN BREATH TEST IN BANGLADESHI CHILDREN',
#  'LONGITUDINAL ASSESSMENT OF ANTIBIOTIC RESISTANCE IN FECAL ESCHERICHIA COLI IN TANZANIAN CHILDREN',
#  'MACHINE LEARNING FOR CLASSIFICATION OF PROTEIN HELIX CAPPING MOTIFS',
#  'MO1992–SOLVING THE STAIN DILEMMA: COMPUTATIONAL IMAGE ANALYSIS TO ADDRESS DIFFERENTIAL TISSUE STAINING COLOR BIAS IN DUODENAL BIOPSIES',
#  'MODELING COMMODITY FLOW IN THE CONTEXT OF INVASIVE SPECIES SPREAD: STUDY OF TUTA ABSOLUTA IN NEPAL',
#  'MODELING URBAN MOBILITY NETWORKS USING CONSTRAINED LABELED SEQUENCES',
#  'MOLECULAR DETERMINANTS OF NEISSERIAL OPA PROTEIN INTERACTIONS WITH HUMAN CEACAMS',
#  'MOLECULAR MODELING OF THE ALPHA GLOBIN/ENOS COMPLEX VIA CROSSLINKING MASS SPECTROMETRY',
#  'OPTIMIZING SPATIAL ALLOCATION OF SEASONAL INFLUENZA VACCINE UNDER TEMPORAL CONSTRAINTS',
#  'QUANTIFYING CARCINOEMBRYONIC ANTIGEN-LIKE CELL ADHESION MOLECULE-TARGETED LIPOSOME DELIVERY USING IMAGING FLOW CYTOMETRY.',
#  'QUANTIFYING CEACAM TARGETED LIPOSOME DELIVERY USING IMAGING FLOW CYTOMETRY',
#  'SCREENING FOR COELIAC DISEASE IN CHILDREN AND ADULTS LIVING IN A SLUM OF DHAKA, BANGLADESH',
#  'SEASONAL FOOD INSECURITY IN HAYDOM, TANZANIA, IS ASSOCIATED WITH LOW BIRTHWEIGHT AND ACUTE MALNUTRITION: RESULTS FROM THE MAL-ED STUDY',
#  'SELF-ATTENTIVE ADVERSARIAL STAIN NORMALIZATION',
#  'STUDY OF ENVIRONMENTAL ENTEROPATHY AND MALNUTRITION (SEEM) IN PAKISTAN: PROTOCOLS FOR BIOPSY BASED BIOMARKER DISCOVERY AND VALIDATION',
#  'SYMMETRY PROPERTIES OF NESTED CANALYZING FUNCTIONS',
#  'THE SMALL Β-BARREL DOMAIN: A SURVEY-BASED STRUCTURAL ANALYSIS',
#  'THE URFOLD: STRUCTURAL SIMILARITY JUST ABOVE THE SUPERFOLD LEVEL?',
#  'TRANSITIONING TOWARDS RESILIENT URBAN WATER SYSTEMS THROUGH TRADITIONAL ENGINEERING AND NATURE-BASED STRATEGIES (REUWS)',
#  'UNDERSTANDING THE HUMANITARIAN WORLD',
#  'VASCULAR EXPRESSION OF HEMOGLOBIN ALPHA IN ANTARCTIC ICEFISH SUPPORTS IRON LIMITATION AS NOVEL EVOLUTIONARY DRIVER'}

# %%
# determine which publications are new since the last scan

# Load the previous scan
old_frame = pandas.read_csv('./results/publication_table.tsv',sep='\t')

# which titles are new?
old_titles = set(old_frame['Title'])
current_titles = set(pub_to_frame['Title'])
new_titles = current_titles - old_titles
new_titles
# Out:
# {'A FRAMEWORK FOR DISCOVERING HEALTH DISPARITIES AMONG COHORTS IN AN INFLUENZA EPIDEMIC',
#  'CELIACNET: CELIAC DISEASE SEVERITY DIAGNOSIS ON DUODENAL HISTOPATHOLOGICAL IMAGES USING DEEP RESIDUAL NETWORKS',
#  'FORECASTING DENGUE AND INFLUENZA INCIDENCES USING A SPARSE REPRESENTATION OF GOOGLE TRENDS, ELECTRONIC HEALTH RECORDS, AND TIME SERIES DATA.',
#  'PERSISTENT POST-DISCHARGE OPIOID PRESCRIBING AFTER TRAUMATIC BRAIN INJURY REQUIRING INTENSIVE CARE UNIT ADMISSION: A CROSS-SECTIONAL STUDY WITH LONGITUDINAL OUTCOME',
#  'RANK AGGREGATION VIA HETEROGENEOUS THURSTONE PREFERENCE MODELS',
#  'THE AAA+ ATPASE TORSINA POLYMERIZES INTO HOLLOW HELICAL TUBES WITH 8.5 SUBUNITS PER TURN'}

# %%
# merge the old and new publication dataframes and re-save
new_publication_data = pandas.concat([old_frame,pub_to_frame.loc[pub_to_frame['Title'].isin(new_titles)]])
new_publication_data.to_csv('./results/publication_table.tsv',sep='\t',index=False)

# %%
# save the list of faculty that don't have google scholar profiles
no_profile
with open('./results/faculty_missing_profiles.txt', 'w') as file_handler:
    for item in no_profile:
        file_handler.write("{}\n".format(item))
